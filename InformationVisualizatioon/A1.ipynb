# %%
import numpy as np
import pandas as pd
import seaborn as sns

# %%
df = pd.read_csv("https://raw.githubusercontent.com/ggobi/ggobi/master/data/olive.csv") 
df
# Out:
#      Unnamed: 0  Region           Area  palmitic  palmitoleic  stearic  oleic  \
# 0             1       1  North-Apulia       1075           75      226   7823
# 1             2       1  North-Apulia       1088           73      224   7709
# 2             3       1  North-Apulia        911           54      246   8113
# 3             4       1  North-Apulia        966           57      240   7952
# 4             5       1  North-Apulia       1051           67      259   7771
# ..          ...     ...            ...       ...          ...      ...    ...
# 567         568       3  West-Liguria       1280          110      290   7490
# 568         569       3  West-Liguria       1060          100      270   7740
# 569         570       3  West-Liguria       1010           90      210   7720
# 570         571       3  West-Liguria        990          120      250   7750
# 571         572       3  West-Liguria        960           80      240   7950
#
# ...

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'Region', 'Area', 'palmitic', 'palmitoleic', 'stearic',
#        'oleic', 'linoleic', 'linolenic', 'arachidic', 'eicosenoic'],
#       dtype='object')

# %%
df[['palmitic', 'palmitoleic', 'stearic']]
# Out:
#      palmitic  palmitoleic  stearic
# 0        1075           75      226
# 1        1088           73      224
# 2         911           54      246
# 3         966           57      240
# 4        1051           67      259
# ..        ...          ...      ...
# 567      1280          110      290
# 568      1060          100      270
# 569      1010           90      210
# 570       990          120      250
# 571       960           80      240
#
# [572 rows x 3 columns]

# %%
plot = sns.pairplot(df[['Region', 'palmitic', 'palmitoleic', 'stearic', 'oleic']], hue="Region", diag_kind="kde")
plot.fig.suptitle("Distribution of fatty acids of olive oil samples", y=1)
# Out:
# Text(0.5, 1, 'Distribution of fatty acids of olive oil samples')

# %%
# Out:
# Text(0.5, 0.98, 'distribution of fatty acids of olive oil samples')
